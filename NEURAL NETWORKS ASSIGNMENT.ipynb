# %% [markdown]
# ## ARTIFICIAL NEURAL NETWORKS

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\sachi\OneDrive\Excler Data science dr.Ganashree\CSV_Files\Alphabets_data.csv")
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\basav\anaconda7\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\basav\anaconda7\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\basav\anaconda7\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\basav\anaconda7\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\basav\anaconda7\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\basav\anaconda7\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\basav\anaconda7\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\basav\anaconda7\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\basav\anaconda7\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\basav\anaconda7\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)

# %%
df.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
df.isnull()
# Out:
#        letter   xbox   ybox  width  height  onpix   xbar   ybar  x2bar  y2bar  \
# 0       False  False  False  False   False  False  False  False  False  False
# 1       False  False  False  False   False  False  False  False  False  False
# 2       False  False  False  False   False  False  False  False  False  False
# 3       False  False  False  False   False  False  False  False  False  False
# 4       False  False  False  False   False  False  False  False  False  False
# ...       ...    ...    ...    ...     ...    ...    ...    ...    ...    ...
# 19995   False  False  False  False   False  False  False  False  False  False
# 19996   False  False  False  False   False  False  False  False  False  False
# 19997   False  False  False  False   False  False  False  False  False  False
# 19998   False  False  False  False   False  False  False  False  False  False
# 19999   False  False  False  False   False  False  False  False  False  False
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      False   False   False  False   False  False   False
# 1      False   False   False  False   False  False   False
# 2      False   False   False  False   False  False   False
# 3      False   False   False  False   False  False   False
# 4      False   False   False  False   False  False   False
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995  False   False   False  False   False  False   False
# 19996  False   False   False  False   False  False   False
# 19997  False   False   False  False   False  False   False
# 19998  False   False   False  False   False  False   False
# 19999  False   False   False  False   False  False   False
#
# [20000 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
# Check the distribution of target labels
print("\nTarget label distribution:")
print(df['letter'].value_counts())
# Out:
# Target label distribution:
# letter
# U    813
# D    805
# P    803
# T    796
# M    792
# A    789
# X    787
# Y    786
# N    783
# Q    783
# F    775
# G    773
# E    768
# B    766
# V    764
# L    761
# R    758
# I    755
# O    753
# W    752
# S    748
# J    747
# K    739
# C    736
# H    734
# Z    734
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar', 'ybar',
#        'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge', 'xedgey',
#        'yedge', 'yedgex'],
#       dtype='object')

# %%
X = df.drop('letter', axis=1)  
y = df['letter']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.0576983 ,  0.29187713, -1.05327668, ..., -0.21908163,
#         -1.4381527 ,  0.12291107],
#        [ 0.51038497,  1.5023577 , -1.05327668, ..., -0.21908163,
#          0.12008142,  1.35944092],
#        [-0.01230945,  1.19973756,  0.43590966, ..., -0.8656262 ,
#         -0.26947711,  0.74117599],
#        ...,
#        [ 1.03307939,  0.59449727,  0.43590966, ...,  2.36709667,
#         -0.65903564, -2.35014863],
#        [-1.0576983 , -1.22122359, -0.55688123, ...,  0.42746295,
#          0.50963994,  0.12291107],
#        [-0.01230945,  0.59449727,  0.43590966, ..., -0.8656262 ,
#         -0.65903564,  0.12291107]])

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_encoded
# Out:
# array([19,  8,  3, ..., 19, 18,  0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)
X_train, X_test, y_train, y_test
# Out:
# (array([[-0.01230945, -0.01074302, -0.06048579, ..., -0.21908163,
#           0.12008142,  0.12291107],
#         [-0.01230945, -0.01074302,  0.43590966, ..., -0.21908163,
#           0.12008142, -0.49535386],
#         [-0.53500387, -0.6159833 , -0.55688123, ...,  0.42746295,
#          -0.65903564, -1.11361878],
#         ...,
#         [-0.53500387, -0.91860345,  0.43590966, ..., -0.8656262 ,
#          -0.26947711,  0.74117599],
#         [-0.53500387,  0.29187713, -0.55688123, ..., -0.21908163,
#          -1.04859417, -0.49535386],
#         [-1.58039272, -1.22122359, -1.54967212, ..., -0.8656262 ,
#          -1.4381527 , -0.49535386]]),
#  array([[-0.53500387, -0.31336316, -0.06048579, ..., -0.8656262 ,
#           1.288757  , -1.11361878],
#         [-0.01230945,  1.19973756,  0.43590966, ...,  1.7205521 ,
#           1.288757  , -1.73188371],
#         [-0.53500387, -0.91860345, -0.06048579, ..., -1.51217078,
#          -0.65903564,  0.12291107],
#         ...,
#         [ 0.51038497,  0.89711742,  0.93230511, ..., -0.21908163,
#           0.12008142,  0.12291107],
#         [-0.01230945, -0.6159833 , -0.06048579, ...,  1.07400752,
#           2.06787406, -1.73188371],
#         [-1.0576983 , -0.6159833 , -0.55688123, ...,  1.7205521 ,
#          -0.65903564,  0.12291107]]),
#  array([ 4,  4, 13, ..., 23,  8,  9]),
#  array([19, 11,  0, ..., 16, 24, 24]))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  
model.add(Dense(64, activation='relu'))  
model.add(Dense(y_train_one_hot.shape[1], activation='softmax'))
# Out:
# C:\Users\basav\anaconda7\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train_one_hot, epochs=10, batch_size=32, validation_data=(X_test, y_test_one_hot))
# Out:
# Epoch 1/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.4401 - loss: 2.0670 - val_accuracy: 0.7782 - val_loss: 0.7901
# Epoch 2/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7837 - loss: 0.7431 - val_accuracy: 0.8425 - val_loss: 0.5537
# Epoch 3/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8417 - loss: 0.5343 - val_accuracy: 0.8730 - val_loss: 0.4377
# Epoch 4/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8768 - loss: 0.4167 - val_accuracy: 0.8925 - val_loss: 0.3723
# Epoch 5/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9002 - loss: 0.3469 - val_accuracy: 0.9078 - val_loss: 0.3139
# Epoch 6/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9144 - loss: 0.2890 - val_accuracy: 0.9122 - val_loss: 0.2869
# Epoch 7/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9254 - loss: 0.2549 - val_accuracy: 0.9193 - val_loss: 0.2643
# Epoch 8/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9345 - loss: 0.2231 - val_accuracy: 0.9255 - val_loss: 0.2356
# Epoch 9/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9382 - loss: 0.2050 - val_accuracy: 0.9268 - val_loss: 0.2304
# Epoch 10/10
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9441 - loss: 0.1856 - val_accuracy: 0.9370 - val_loss: 0.2008

# %%
loss, accuracy = model.evaluate(X_test, y_test_one_hot)
print("\nTest Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9346 - loss: 0.1988
#
# Test Accuracy: 93.70%

# %%
2+3
# Out:
# 5

# %%
# !python -m venv new_env

# %%
# !pip install tensorflow scikit-learn keras-tuner
# Out:
# Requirement already satisfied: tensorflow in c:\users\basav\anaconda7\lib\site-packages (2.18.0)
# Requirement already satisfied: scikit-learn in c:\users\basav\anaconda7\lib\site-packages (1.4.2)
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\basav\anaconda7\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\basav\anaconda7\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basav\anaconda7\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: rich in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\basav\anaconda7\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\basav\anaconda7\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\basav\anaconda7\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\basav\anaconda7\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\basav\anaconda7\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\basav\appdata\roaming\python\python312\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\basav\anaconda7\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\basav\anaconda7\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ---------------------------------------- 0.0/129.1 kB ? eta -:--:--
#    ------ -------------------------------- 20.5/129.1 kB 330.3 kB/s eta 0:00:01
#    ---------------------------- ----------- 92.2/129.1 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 129.1/129.1 kB 1.1 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
def create_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units', min_value=32, max_value=128, step=32), input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(y_train_one_hot.shape[1], activation='softmax'))  
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[0.001, 0.01, 0.1])),
        metrics=['accuracy']
    )
    return model

# %%
tuner = kt.Hyperband(
    create_model,
    objective='val_accuracy',
    max_epochs=10,
    factor=3,
    directory='keras_tuner',
    project_name='alphabet_model'
)
# Out:
# C:\Users\basav\anaconda7\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tuner.search(X_train, y_train_one_hot, epochs=10, validation_data=(X_test, y_test_one_hot))
# Out:
# Trial 11 Complete [00h 00m 09s]
# val_accuracy: 0.706250011920929
#
# Best val_accuracy So Far: 0.8960000276565552
# Total elapsed time: 00h 01m 41s

# %%
best_model = tuner.get_best_models(num_models=1)[0]
loss, accuracy = best_model.evaluate(X_test, y_test_one_hot)
print("\nTest Accuracy with Best Hyperparameters: {:.2f}%".format(accuracy * 100))
# Out:
# C:\Users\basav\anaconda7\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\basav\anaconda7\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8953 - loss: 0.3204
#
# Test Accuracy with Best Hyperparameters: 89.60%

# %%
from sklearn.metrics import classification_report

# Get predictions
y_pred = model.predict(X_test)

# Convert predictions and true labels back from one-hot encoding
y_pred_labels = encoder.inverse_transform(y_pred.argmax(axis=1))
y_test_labels = encoder.inverse_transform(y_test)

# Print classification report
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred_labels))
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.97      0.99      0.98       149
#            B       0.91      0.91      0.91       153
#            C       0.96      0.91      0.93       137
#            D       0.90      0.94      0.92       156
#            E       0.91      0.94      0.92       141
#            F       0.82      0.95      0.88       140
#            G       0.94      0.93      0.93       160
#            H       0.83      0.86      0.85       144
#            I       0.95      0.97      0.96       146
#            J       0.97      0.93      0.95       149
#            K       0.90      0.85      0.87       130
#            L       0.96      0.97      0.96       155
#            M       0.97      0.97      0.97       168
#            N       0.97      0.93      0.95       151
#            O       0.94      0.94      0.94       145
#            P       1.00      0.86      0.92       173
#            Q       0.97      0.98      0.97       166
#            R       0.85      0.88      0.87       160
#            S       0.97      0.95      0.96       171
#            T       0.99      0.96      0.97       163
#            U       0.94      0.94      0.94       183
#            V       0.97      0.93      0.95       158
#            W       0.91      0.98      0.94       148
#            X       0.94      0.99      0.96       154
#            Y       0.96      0.96      0.96       168
#            Z       0.96      0.95      0.96       132
#
#     accuracy                           0.94      4000
#    macro avg       0.94      0.94      0.94      4000
# weighted avg       0.94      0.94      0.94      4000
